# %%
import torch as T
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import pandas as pd
import random
from utils import plot_learning_curve

# %%
class TwoInputsNet(nn.Module):
    # ****
    # tengo que revisar mejor sobre los channels y toda esta locura porque hay algo raro. sobretodo en la parte de los filtros.
    
    # revisa que todas tus dimensiones esten correctas.
    # ****
    def __init__(self, lr, in_channels, out_channels, kernel_size, input_dims, fc1_dims, fc2_dims, n_actions):
        super(TwoInputsNet, self).__init__()
        self.conv_open = nn.Conv1d(in_channels, out_channels, kernel_size)
        self.conv_high = nn.Conv1d(in_channels, out_channels, kernel_size)
        self.conv_low = nn.Conv1d(in_channels, out_channels, kernel_size)
        self.conv_close = nn.Conv1d(in_channels, out_channels, kernel_size)
        self.conv_volume = nn.Conv1d(in_channels, out_channels, kernel_size)
        self.fc_state = nn.Linear(2, 2)
        
        self.fc1 = nn.Linear(input_dims, fc1_dims) #input dims is the sum of all outputs of the conv layers.
        self.fc2 = nn.Linear(fc1_dims, fc2_dims)
        self.fc3 = nn.Linear(fc2_dims, n_actions)
        
        self.optimizer = optim.Adam(self.parameters(), lr = lr)
        self.loss = nn.MSELoss()
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')
        
        # Open High Low Close Volume in that order (also for the numpy array)
        # input6 son dos nodos de input para saber si el agente ha comprado/vendido y en cuanto.
    def forward(self, input1, input2, input3, input4, input5, input6):
        c1 = self.conv_open(input1.unsqueeze(dim = 1))
        c2 = self.conv_high(input2.unsqueeze(dim = 1))
        c3 = self.conv_low(input3.unsqueeze(dim = 1))
        c4 = self.conv_close(input4.unsqueeze(dim = 1))
        c5 = self.conv_volume(input5.unsqueeze(dim = 1))
        f1 = self.fc_state(input6)
        
        # now we can reshape to 2D and concat them
        combined = T.cat((c1.view(c1.size(0), -1), 
                          c2.view(c2.size(0), -1),
                          c3.view(c3.size(0), -1),
                          c4.view(c4.size(0), -1),
                          c5.view(c5.size(0), -1),
                          f1.view(f1.size(0), -1)), dim=1)
        
        x = F.relu(self.fc1(combined))
        x = F.relu(self.fc2(x))
        actions = self.fc3(x)
        
        return actions
    
class Agent():
    def __init__(self, gamma, epsilon, lr, input_dims1, input_dims2, batch_size, n_actions,
                max_mem_size = 100000, eps_end=0.01, eps_dec=5e-4):
        self.gamma = gamma
        self.epsilon = epsilon
        self.eps_min = eps_end
        self.eps_dec = eps_dec
        self.lr = lr
        self.action_space = [i for i in range(n_actions)]
        self.mem_size = max_mem_size
        self.batch_size = batch_size
        self.mem_cntr = 0
        
        # self.Q_eval = DeepQNetwork(self.lr, n_actions = n_actions, input_dims=input_dims, fc1_dims=256, fc2_dims=256)
        # (self, lr, in_channels, out_channels, kernel_size, input_dims, fc1_dims, fc2_dims, n_actions)
        
        self.Q_eval = TwoInputsNet(self.lr, 1, 4, 3, 562, 64, 64, n_actions)
        # ***
        # tengo que reviar si el replay memory esta funcionando correctamente, sobre todo el *input_dims
        # as of now I checked the state_memory shape (10000, 30, 5) and it looks correct
        # ***
        self.state_memory = np.zeros((self.mem_size, *input_dims1), dtype = np.float32)
        self.state_memory2 = np.zeros((self.mem_size, *input_dims2), dtype = np.float32)
        self.new_state_memory = np.zeros((self.mem_size, *input_dims1), dtype=np.float32)
        self.new_state_memory2 = np.zeros((self.mem_size, *input_dims2), dtype=np.float32)
        self.action_memory = np.zeros(self.mem_size, dtype=np.int32)
        self.reward_memory = np.zeros(self.mem_size, dtype=np.float32)
        self.terminal_memory = np.zeros(self.mem_size, dtype=np.bool)
        
    def store_transition(self, state, action, reward, state_, done):
        index = self.mem_cntr % self.mem_size
        self.state_memory[index] = state[0]
        self.state_memory2[index] = state[1]
        self.new_state_memory[index] = state_[0]
        self.new_state_memory2[index] = state_[1]
        self.reward_memory[index] = reward
        self.action_memory[index] = action
        self.terminal_memory[index] = done
        
        self.mem_cntr += 1
        
    def choose_action(self, observation):
        if np.random.random() > self.epsilon:
            # aqui tuve que separar la observacion en las 2 partes y transformarlas a pytorch tensor. 
            # no se si es lo mejor, pero sirve asi que...
            
            state = T.tensor([observation[0]]).to(self.Q_eval.device)
            state2 = T.tensor([observation[1]]).to(self.Q_eval.device)
#             print(state)
            actions = self.Q_eval.forward(state[:,:,0], 
                                          state[:,:,1], 
                                          state[:,:,2], 
                                          state[:,:,3], 
                                          state[:,:,4],
                                          state2[:])
            action = T.argmax(actions).item()
        else:
            action = np.random.choice(self.action_space)
            
        return action
    
    def learn(self):
        if self.mem_cntr < self.batch_size:
            return
        self.Q_eval.optimizer.zero_grad()
        
        max_mem = min(self.mem_cntr, self.mem_size)
        batch = np.random.choice(max_mem, self.batch_size, replace=False)
        
        batch_index = np.arange(self.batch_size, dtype=np.int32)
        
        state_batch = T.tensor(self.state_memory[batch]).to(self.Q_eval.device)
        state_batch2 = T.tensor(self.state_memory2[batch]).to(self.Q_eval.device)
        new_state_batch = T.tensor(self.new_state_memory[batch]).to(self.Q_eval.device)
        new_state_batch2 = T.tensor(self.new_state_memory2[batch]).to(self.Q_eval.device)
        reward_batch = T.tensor(self.reward_memory[batch]).to(self.Q_eval.device)
        terminal_batch = T.tensor(self.terminal_memory[batch]).to(self.Q_eval.device)
        
        action_batch = self.action_memory[batch]

        q_eval = self.Q_eval.forward(state_batch[:,:,0], 
                                     state_batch[:,:,1], 
                                     state_batch[:,:,2], 
                                     state_batch[:,:,3], 
                                     state_batch[:,:,4],
                                     state_batch2[:])[batch_index, action_batch]
    
        q_next = self.Q_eval.forward(new_state_batch[:,:,0], 
                                     new_state_batch[:,:,1], 
                                     new_state_batch[:,:,2], 
                                     new_state_batch[:,:,3], 
                                     new_state_batch[:,:,4],
                                     new_state_batch2[:])
        q_next[terminal_batch] = 0.0
        
        q_target = reward_batch + self.gamma * T.max(q_next, dim=1)[0]
        
        loss = self.Q_eval.loss(q_target, q_eval).to(self.Q_eval.device)
        loss.backward()
        self.Q_eval.optimizer.step()
        
        self.epsilon = self.epsilon - self.eps_dec if self.epsilon > self.eps_min \
                        else self.eps_min

# %%
# ***
# tienes que refactorizar esta vaina porque no se sabe si verdaderamente sirve esta porqueria y ta escrito bien feo
# tambien hay que agregar cosas el env para que sea mas realistico (como el tax cuando compras/vendes)
# hay una vaina rara con las dimensiones de la observacion asi que tendras que revisar eso tambien para ver si sirve bien.
# ***


class environment:
    # you pass the historical data as a numpy array to the init.
    # first you have to save the price at the time of the action.  
    # 
    
    def __init__(self, historical_data, observation_size):
        self.historical_data = historical_data
        
        self.leverage = 10
        self.action_history = []
        self.buy_sell = None # variable to know if the first position is either a buy or a sell; buy = 0, sell = 1
        self.current_price = None
        self.initial_price = None
        self.reward = 0
        self.timesteps = 0
        self.observation = None
        self.info = None #unused as of now
        self.done = None
        self.current_position = None
        self.start_position = None
        self.observation_size = observation_size
        self.first_run = True
        # test
        self.buy_sell_price_obs = np.array([0, 0], dtype = np.float32)
        self.full_observation = []
        

        
    def step(self, action):
        # get action and return what the agent needs. take into account the penalty for instantly buying and selling.
        # as of now I plan to do it as an episodic task, I will have to check this approach as it could bring problems later.
        # episode ends when agent gets a return(ie, buys then sells or sells then buys)
        # reward is the profit that the agent gets at the end of the episode
        # info might be how many timesteps the episode lasted
        # think about implementing variable reward or reward decaying to get certain behaviours early on.
        # maybe we should penalize consecutive buys and consecutive sells?
        # maybe the agent should know if he's bought or sold previuosly in this episode? (almost definitely) (encoding/0,1,2)
        # the agent should also know the price that he bought at. (as an input to the neural network) 
        # now that I think about it, the reward cant be just profit, it has to be the ratio of investment to return so that the
        # reward remains constant.
        self.first_run = False
        self.reward = 0
        
        
        self.timesteps = self.timesteps + 1
        self.current_position = self.start_position + self.timesteps 
        self.observation = self.historical_data[self.current_position - self.observation_size : self.current_position]
        self.current_price = self.observation[self.observation_size - 1, 3] #get current price based on current position
        
        
        if action == 0:
            # you dont actually have to do much
            self.done = False
            self.reward = 0
            
        if action == 1:
            self.done = False
            self.reward = 0
            
            #first buy
            if self.buy_sell == None:
                self.buy_sell = 0
                self.buy_sell_price_obs[0] = 1
                self.buy_sell_price_obs[1] = self.current_price
            
            # buy buy
            if self.buy_sell == 0:
                self.action_history.append(self.initial_price)
            # sell buy    
            if self.buy_sell == 1:
                #get all prices and get the total profit
                # remember that the calculation is done in the opposite side. so this calculation is for selling then buying
                # and the return is positive when the current price is lower than the initial price
                for price in self.action_history:
                    self.reward = self.reward + (price * self.leverage) - (self.current_price * self.leverage)
                
                self.done = True
                print("The episode ran for {} timesteps.".format(self.timesteps))
                self.observation = self.reset()
                
            
        if action == 2:
            self.done = False
            self.reward = 0
            
            #first sell
            if self.buy_sell == None:
                self.buy_sell = 1
                self.buy_sell_price_obs[0] = 2
                self.buy_sell_price_obs[1] = self.current_price
                
            # sell sell
            if self.buy_sell == 1:
                self.action_history.append(self.initial_price)
            # buy sell
            if self.buy_sell == 0:
                # get all prices and get total profit
                # remember that the calculation is done in the opposite side. so this calculation is for buying then selling
                # and the return is positive when the current price is higher than the initial price
                for price in self.action_history:
                    self.reward = self.reward - (price * self.leverage) + (self.current_price * self.leverage)
                
                self.done = True
                print("The episode ran for {} timesteps.".format(self.timesteps))
                self.observation = self.reset()
                
            
        # full_observations is a [2] list which has the price action observation [observation_size, 5]
        # and buy_sell_price_obs [2] con la memoria de la accion y el precio al momento de la accion. 
        
        self.observation_full = []
        self.full_observation = [self.observation, self.buy_sell_price_obs]
#         print(self.full_observation)
        return self.full_observation, self.reward, self.done, self.info
    
    def reset(self):
        # get random starting point in historical data and return the first point as an observation.
        # reset all variables used for the episode
        
        # you have to check more thoroughly to determine which variables you dont have to reset
        # this is so that you can return properly on the env.step() function.
        
        self.action_history = []
        self.buy_sell = None # variable to know if the first position is either a buy or a sell; buy = 0, sell = 1
        self.current_price = None
        self.initial_price = None
#         if self.first_run:
#             print("The episode ran for {} timesteps.".format(self.timesteps))
        self.timesteps = 0
        self.observation = None
        self.current_position = None
        self.start_position = None
        self.first_price_action = 0
        
        # test
        self.buy_sell_price_obs = np.array([0, 0], dtype = np.float32)
        self.observation_full = []
        
        
        self.start_position = random.randint(30, 45000)#get random number to start
#         print(self.start_position)
        observation = self.historical_data[self.start_position - self.observation_size : self.start_position]
        self.initial_price = observation[self.observation_size - 1, 3]
        # test
        if self.first_run:
            self.full_observation = [observation, self.buy_sell_price_obs]
            return self.full_observation
        self.first_run = True
        return observation

# %%
historical_data = pd.read_csv(r'C:\Users\ratatosck\Desktop\pythonScripts\TradeBot\HistoricalData\EURUSD15.csv', sep='\t',header=None)
historical_data.drop(0, axis=1, inplace = True)
y = historical_data.to_numpy(dtype = 'float32')
env = environment(y, 30)

agent = Agent(gamma = 0.99, epsilon = 1.0, batch_size=64, n_actions = 3, 
             eps_end = 0.01, input_dims1 = [30, 5], input_dims2 = [2], lr=0.003)
scores, eps_history = [], []
n_games = 1000

for i in range (n_games):
    score = 0
    done = False
    observation = env.reset()
    while not done:
        action = agent.choose_action(observation)
        observation_, reward, done, info = env.step(action)
        score += reward
        agent.store_transition(observation, action, reward, observation_, done)
        agent.learn()
        observation = observation_
    scores.append(score)
    eps_history.append(agent.epsilon)

    avg_score = np.mean(scores[-100:])

    print('episode', i, 'score %.2f' % score, 
             'average score %.2f' % avg_score,
             'epsilon %.2f'% agent.epsilon)
        
x = [i+1 for i in range(n_games)]
filename = 'results'
plot_learning_curve(x, scores, eps_history, filename)
# Out:
# The episode ran for 4 timesteps.
# episode 0 score -0.03 average score -0.03 epsilon 1.00
# The episode ran for 4 timesteps.
# episode 1 score -0.00 average score -0.02 epsilon 1.00
# The episode ran for 2 timesteps.
# episode 2 score 0.00 average score -0.01 epsilon 1.00
# The episode ran for 3 timesteps.
# episode 3 score 0.00 average score -0.01 epsilon 1.00
# The episode ran for 3 timesteps.
# episode 4 score -0.00 average score -0.00 epsilon 1.00
# The episode ran for 2 timesteps.
# episode 5 score 0.00 average score -0.00 epsilon 1.00
# The episode ran for 2 timesteps.
# episode 6 score 0.00 average score -0.00 epsilon 1.00
# The episode ran for 5 timesteps.
# episode 7 score 0.05 average score 0.00 epsilon 1.00
# The episode ran for 9 timesteps.
# episode 8 score 0.21 average score 0.03 epsilon 1.00
# The episode ran for 3 timesteps.
# episode 9 score -0.01 average score 0.02 epsilon 1.00
# The episode ran for 10 timesteps.
# episode 10 score 0.03 average score 0.03 epsilon 1.00
# The episode ran for 3 timesteps.
# episode 11 score 0.01 average score 0.02 epsilon 1.00
# The episode ran for 3 timesteps.
# episode 12 score -0.00 average score 0.02 epsilon 1.00
# The episode ran for 7 timesteps.
# episode 13 score 0.00 average score 0.02 epsilon 1.00
# The episode ran for 4 timesteps.
# episode 14 score -0.04 average score 0.02 epsilon 1.00
# The episode ran for 2 timesteps.
# episode 15 score 0.00 average score 0.02 epsilon 1.00
# The episode ran for 8 timesteps.
# episode 16 score 0.01 average score 0.01 epsilon 0.99
# The episode ran for 3 timesteps.
# episode 17 score 0.01 average score 0.01 epsilon 0.99
# The episode ran for 2 timesteps.
# episode 18 score 0.01 average score 0.01 epsilon 0.99
# The episode ran for 3 timesteps.
# episode 19 score -0.01 average score 0.01 epsilon 0.99
# The episode ran for 2 timesteps.
# episode 20 score -0.01 average score 0.01 epsilon 0.99
# The episode ran for 10 timesteps.
# episode 21 score -0.05 average score 0.01 epsilon 0.98
# The episode ran for 4 timesteps.
# episode 22 score -0.00 average score 0.01 epsilon 0.98
# The episode ran for 2 timesteps.
# episode 23 score 0.00 average score 0.01 epsilon 0.98
# The episode ran for 18 timesteps.
# episode 24 score -0.03 average score 0.01 epsilon 0.97
# The episode ran for 2 timesteps.
# episode 25 score -0.00 average score 0.01 epsilon 0.97
# The episode ran for 6 timesteps.
# episode 26 score 0.05 average score 0.01 epsilon 0.97
# The episode ran for 5 timesteps.
# episode 27 score 0.01 average score 0.01 epsilon 0.97
# The episode ran for 5 timesteps.
# episode 28 score 0.00 average score 0.01 epsilon 0.96
# The episode ran for 3 timesteps.
# episode 29 score 0.00 average score 0.01 epsilon 0.96
# The episode ran for 2 timesteps.
# episode 30 score 0.01 average score 0.01 epsilon 0.96
# The episode ran for 2 timesteps.
# episode 31 score 0.01 average score 0.01 epsilon 0.96
# The episode ran for 4 timesteps.
# episode 32 score -0.00 average score 0.01 epsilon 0.96
# The episode ran for 5 timesteps.
# episode 33 score 0.00 average score 0.01 epsilon 0.96
# The episode ran for 3 timesteps.
# episode 34 score -0.00 average score 0.01 epsilon 0.95
# The episode ran for 3 timesteps.
# episode 35 score -0.00 average score 0.01 epsilon 0.95
# The episode ran for 4 timesteps.
# episode 36 score 0.01 average score 0.01 epsilon 0.95
# The episode ran for 2 timesteps.
# episode 37 score -0.00 average score 0.01 epsilon 0.95
# The episode ran for 7 timesteps.
# episode 38 score -0.01 average score 0.01 epsilon 0.95
# The episode ran for 5 timesteps.
# episode 39 score -0.00 average score 0.01 epsilon 0.94
# The episode ran for 2 timesteps.
# episode 40 score -0.00 average score 0.01 epsilon 0.94
# The episode ran for 2 timesteps.
# episode 41 score -0.00 average score 0.01 epsilon 0.94
# The episode ran for 3 timesteps.
# episode 42 score 0.02 average score 0.01 epsilon 0.94
# The episode ran for 5 timesteps.
# episode 43 score 0.01 average score 0.01 epsilon 0.94
# The episode ran for 4 timesteps.
# episode 44 score 0.01 average score 0.01 epsilon 0.94
# The episode ran for 10 timesteps.
# episode 45 score -0.21 average score 0.00 epsilon 0.93
# The episode ran for 4 timesteps.
# episode 46 score 0.00 average score 0.00 epsilon 0.93
# The episode ran for 6 timesteps.
# episode 47 score 0.01 average score 0.00 epsilon 0.93
# The episode ran for 7 timesteps.
# episode 48 score 0.01 average score 0.00 epsilon 0.92
# The episode ran for 4 timesteps.
# episode 49 score -0.00 average score 0.00 epsilon 0.92
# The episode ran for 10 timesteps.
# episode 50 score 0.05 average score 0.00 epsilon 0.92
# The episode ran for 2 timesteps.
# episode 51 score -0.01 average score 0.00 epsilon 0.91
# The episode ran for 6 timesteps.
# episode 52 score -0.01 average score 0.00 epsilon 0.91
# The episode ran for 3 timesteps.
# episode 53 score -0.01 average score 0.00 epsilon 0.91
# The episode ran for 2 timesteps.
# episode 54 score 0.00 average score 0.00 epsilon 0.91
# The episode ran for 3 timesteps.
# episode 55 score 0.01 average score 0.00 epsilon 0.91
# The episode ran for 7 timesteps.
# episode 56 score 0.02 average score 0.00 epsilon 0.90
# The episode ran for 5 timesteps.
# episode 57 score -0.00 average score 0.00 epsilon 0.90
# The episode ran for 6 timesteps.
# episode 58 score 0.00 average score 0.00 epsilon 0.90
# The episode ran for 4 timesteps.
# episode 59 score -0.00 average score 0.00 epsilon 0.90
# The episode ran for 6 timesteps.
# episode 60 score -0.01 average score 0.00 epsilon 0.89
# The episode ran for 2 timesteps.
# episode 61 score -0.00 average score 0.00 epsilon 0.89
# The episode ran for 4 timesteps.
# episode 62 score 0.00 average score 0.00 epsilon 0.89
# The episode ran for 6 timesteps.
# episode 63 score -0.01 average score 0.00 epsilon 0.89
# The episode ran for 3 timesteps.
# episode 64 score 0.00 average score 0.00 epsilon 0.89
# The episode ran for 6 timesteps.
# episode 65 score 0.05 average score 0.00 epsilon 0.88
# The episode ran for 4 timesteps.
# episode 66 score -0.01 average score 0.00 epsilon 0.88
# The episode ran for 3 timesteps.
# episode 67 score 0.00 average score 0.00 epsilon 0.88
# The episode ran for 2 timesteps.
# episode 68 score -0.00 average score 0.00 epsilon 0.88
# The episode ran for 2 timesteps.
# episode 69 score 0.00 average score 0.00 epsilon 0.88
# The episode ran for 2 timesteps.
# episode 70 score 0.00 average score 0.00 epsilon 0.88
# The episode ran for 4 timesteps.
# episode 71 score 0.00 average score 0.00 epsilon 0.87
# The episode ran for 6 timesteps.
# episode 72 score 0.00 average score 0.00 epsilon 0.87
# The episode ran for 2 timesteps.
# episode 73 score -0.00 average score 0.00 epsilon 0.87
# The episode ran for 3 timesteps.
# episode 74 score 0.02 average score 0.00 epsilon 0.87
# The episode ran for 3 timesteps.
# episode 75 score -0.01 average score 0.00 epsilon 0.87
# The episode ran for 6 timesteps.
# episode 76 score -0.00 average score 0.00 epsilon 0.86
# The episode ran for 6 timesteps.
# episode 77 score 0.00 average score 0.00 epsilon 0.86
# The episode ran for 3 timesteps.
# episode 78 score -0.00 average score 0.00 epsilon 0.86
# The episode ran for 2 timesteps.
# episode 79 score -0.01 average score 0.00 epsilon 0.86
# The episode ran for 5 timesteps.
# episode 80 score 0.01 average score 0.00 epsilon 0.86
# The episode ran for 4 timesteps.
# episode 81 score -0.01 average score 0.00 epsilon 0.85
# The episode ran for 7 timesteps.
# episode 82 score 0.00 average score 0.00 epsilon 0.85
# The episode ran for 6 timesteps.
# episode 83 score 0.13 average score 0.00 epsilon 0.85
# The episode ran for 8 timesteps.
# episode 84 score -0.00 average score 0.00 epsilon 0.84
# The episode ran for 11 timesteps.
# episode 85 score 0.03 average score 0.00 epsilon 0.84
# The episode ran for 2 timesteps.
# episode 86 score -0.02 average score 0.00 epsilon 0.84
# The episode ran for 5 timesteps.
# episode 87 score 0.01 average score 0.00 epsilon 0.83
# The episode ran for 8 timesteps.
# episode 88 score -0.02 average score 0.00 epsilon 0.83
# The episode ran for 4 timesteps.
# episode 89 score 0.01 average score 0.00 epsilon 0.83
# The episode ran for 17 timesteps.
# episode 90 score 0.01 average score 0.00 epsilon 0.82
# The episode ran for 6 timesteps.
# episode 91 score 0.01 average score 0.00 epsilon 0.82
# The episode ran for 2 timesteps.
# episode 92 score 0.00 average score 0.00 epsilon 0.82
# The episode ran for 4 timesteps.
# episode 93 score -0.02 average score 0.00 epsilon 0.81
# The episode ran for 3 timesteps.
# episode 94 score 0.00 average score 0.00 epsilon 0.81
# The episode ran for 4 timesteps.
# episode 95 score -0.02 average score 0.00 epsilon 0.81
# The episode ran for 6 timesteps.
# episode 96 score 0.01 average score 0.00 epsilon 0.81
# The episode ran for 8 timesteps.
# episode 97 score -0.18 average score 0.00 epsilon 0.80
# The episode ran for 5 timesteps.
# episode 98 score 0.01 average score 0.00 epsilon 0.80
# The episode ran for 4 timesteps.
# episode 99 score -0.00 average score 0.00 epsilon 0.80
# The episode ran for 6 timesteps.
# episode 100 score 0.00 average score 0.00 epsilon 0.80
# The episode ran for 3 timesteps.
# episode 101 score -0.00 average score 0.00 epsilon 0.79
# The episode ran for 2 timesteps.
# episode 102 score -0.00 average score 0.00 epsilon 0.79
# The episode ran for 8 timesteps.
# episode 103 score -0.02 average score 0.00 epsilon 0.79
# The episode ran for 5 timesteps.
# episode 104 score 0.01 average score 0.00 epsilon 0.79
# The episode ran for 2 timesteps.
# episode 105 score 0.01 average score 0.00 epsilon 0.79
# The episode ran for 2 timesteps.
# episode 106 score -0.00 average score 0.00 epsilon 0.79
# The episode ran for 6 timesteps.
# episode 107 score 0.01 average score 0.00 epsilon 0.78
# The episode ran for 3 timesteps.
# episode 108 score -0.02 average score -0.00 epsilon 0.78
# The episode ran for 2 timesteps.
# episode 109 score -0.01 average score -0.00 epsilon 0.78
# The episode ran for 3 timesteps.
# episode 110 score -0.00 average score -0.00 epsilon 0.78
# The episode ran for 7 timesteps.
# episode 111 score 0.01 average score -0.00 epsilon 0.77
# The episode ran for 4 timesteps.
# episode 112 score 0.02 average score -0.00 epsilon 0.77
# The episode ran for 8 timesteps.
# episode 113 score -0.01 average score -0.00 epsilon 0.77
# The episode ran for 9 timesteps.
# episode 114 score 0.05 average score -0.00 epsilon 0.76
# The episode ran for 3 timesteps.
# episode 115 score -0.00 average score -0.00 epsilon 0.76
# The episode ran for 4 timesteps.
# episode 116 score 0.00 average score -0.00 epsilon 0.76
# The episode ran for 6 timesteps.
# episode 117 score -0.00 average score -0.00 epsilon 0.76
# The episode ran for 4 timesteps.
# episode 118 score 0.01 average score -0.00 epsilon 0.76
# The episode ran for 3 timesteps.
# episode 119 score -0.01 average score -0.00 epsilon 0.75
# The episode ran for 6 timesteps.
# episode 120 score 0.01 average score -0.00 epsilon 0.75
# The episode ran for 4 timesteps.
# episode 121 score 0.00 average score -0.00 epsilon 0.75
# The episode ran for 6 timesteps.
# episode 122 score -0.01 average score -0.00 epsilon 0.75
# The episode ran for 4 timesteps.
# episode 123 score -0.01 average score -0.00 epsilon 0.74
# The episode ran for 4 timesteps.
# episode 124 score 0.00 average score -0.00 epsilon 0.74
# The episode ran for 5 timesteps.
# episode 125 score -0.00 average score -0.00 epsilon 0.74
# The episode ran for 2 timesteps.
# episode 126 score -0.00 average score -0.00 epsilon 0.74
# The episode ran for 6 timesteps.
# episode 127 score 0.00 average score -0.00 epsilon 0.74
# The episode ran for 3 timesteps.
# episode 128 score 0.01 average score -0.00 epsilon 0.73
# The episode ran for 2 timesteps.
# episode 129 score 0.00 average score -0.00 epsilon 0.73
# The episode ran for 5 timesteps.
# episode 130 score 0.03 average score -0.00 epsilon 0.73
# The episode ran for 6 timesteps.
# episode 131 score 0.01 average score -0.00 epsilon 0.73
# The episode ran for 2 timesteps.
# episode 132 score -0.01 average score -0.00 epsilon 0.73
# The episode ran for 2 timesteps.
# episode 133 score 0.01 average score -0.00 epsilon 0.73
# The episode ran for 2 timesteps.
# episode 134 score -0.00 average score -0.00 epsilon 0.72
# The episode ran for 3 timesteps.
# episode 135 score 0.00 average score -0.00 epsilon 0.72
# The episode ran for 6 timesteps.
# episode 136 score 0.01 average score -0.00 epsilon 0.72
# The episode ran for 4 timesteps.
# episode 137 score 0.04 average score -0.00 epsilon 0.72
# The episode ran for 2 timesteps.
# episode 138 score -0.00 average score -0.00 epsilon 0.72
# The episode ran for 4 timesteps.
# episode 139 score -0.00 average score -0.00 epsilon 0.72
# The episode ran for 2 timesteps.
# episode 140 score 0.00 average score 0.00 epsilon 0.71
# The episode ran for 5 timesteps.
# episode 141 score -0.00 average score -0.00 epsilon 0.71
# The episode ran for 7 timesteps.
# episode 142 score 0.04 average score 0.00 epsilon 0.71
# The episode ran for 3 timesteps.
# episode 143 score -0.00 average score 0.00 epsilon 0.71
# The episode ran for 3 timesteps.
# episode 144 score 0.00 average score -0.00 epsilon 0.71
# The episode ran for 4 timesteps.
# episode 145 score -0.00 average score 0.00 epsilon 0.70
# The episode ran for 7 timesteps.
# episode 146 score -0.00 average score 0.00 epsilon 0.70
# The episode ran for 6 timesteps.
# episode 147 score 0.01 average score 0.00 epsilon 0.70
# The episode ran for 5 timesteps.
# episode 148 score 0.01 average score 0.00 epsilon 0.69
# The episode ran for 7 timesteps.
# episode 149 score -0.01 average score 0.00 epsilon 0.69
# The episode ran for 2 timesteps.
# episode 150 score -0.01 average score 0.00 epsilon 0.69
# The episode ran for 5 timesteps.
# episode 151 score 0.01 average score 0.00 epsilon 0.69
# The episode ran for 3 timesteps.
# episode 152 score -0.00 average score 0.00 epsilon 0.69
# The episode ran for 10 timesteps.
# episode 153 score -0.02 average score 0.00 epsilon 0.68
# The episode ran for 5 timesteps.
# episode 154 score -0.06 average score 0.00 epsilon 0.68
# The episode ran for 4 timesteps.
# episode 155 score -0.00 average score 0.00 epsilon 0.68
# The episode ran for 3 timesteps.
# episode 156 score -0.00 average score 0.00 epsilon 0.67
# The episode ran for 4 timesteps.
# episode 157 score 0.00 average score 0.00 epsilon 0.67
# The episode ran for 2 timesteps.
# episode 158 score -0.00 average score 0.00 epsilon 0.67
# The episode ran for 6 timesteps.
# episode 159 score 0.08 average score 0.00 epsilon 0.67
# The episode ran for 2 timesteps.
# episode 160 score 0.00 average score 0.00 epsilon 0.67
# The episode ran for 3 timesteps.
# episode 161 score 0.01 average score 0.00 epsilon 0.67
# The episode ran for 3 timesteps.
# episode 162 score 0.00 average score 0.00 epsilon 0.66
# The episode ran for 5 timesteps.
# episode 163 score -0.00 average score 0.00 epsilon 0.66
# The episode ran for 4 timesteps.
# episode 164 score 0.01 average score 0.00 epsilon 0.66
# The episode ran for 7 timesteps.
# episode 165 score -0.00 average score 0.00 epsilon 0.66
# The episode ran for 13 timesteps.
# episode 166 score 0.01 average score 0.00 epsilon 0.65
# The episode ran for 6 timesteps.
# episode 167 score 0.01 average score 0.00 epsilon 0.65
# The episode ran for 10 timesteps.
# episode 168 score 0.02 average score 0.00 epsilon 0.64
# The episode ran for 6 timesteps.
# episode 169 score -0.00 average score 0.00 epsilon 0.64
# The episode ran for 4 timesteps.
# episode 170 score 0.01 average score 0.00 epsilon 0.64
# The episode ran for 4 timesteps.
# episode 171 score 0.00 average score 0.00 epsilon 0.64
# The episode ran for 5 timesteps.
# episode 172 score 0.02 average score 0.00 epsilon 0.63
# The episode ran for 5 timesteps.
# episode 173 score 0.02 average score 0.00 epsilon 0.63
# The episode ran for 15 timesteps.
# episode 174 score -0.28 average score -0.00 epsilon 0.62
# The episode ran for 7 timesteps.
# episode 175 score -0.00 average score -0.00 epsilon 0.62
# The episode ran for 4 timesteps.
# episode 176 score 0.00 average score -0.00 epsilon 0.62
# The episode ran for 2 timesteps.
# episode 177 score -0.00 average score -0.00 epsilon 0.62
# The episode ran for 4 timesteps.
# episode 178 score 0.01 average score -0.00 epsilon 0.61
# The episode ran for 4 timesteps.
# episode 179 score 0.00 average score -0.00 epsilon 0.61
# The episode ran for 4 timesteps.
# episode 180 score 0.02 average score -0.00 epsilon 0.61
# The episode ran for 2 timesteps.
# episode 181 score 0.01 average score 0.00 epsilon 0.61
# The episode ran for 2 timesteps.
# episode 182 score 0.00 average score 0.00 epsilon 0.61
# The episode ran for 4 timesteps.
# episode 183 score -0.00 average score -0.00 epsilon 0.61
# The episode ran for 6 timesteps.
# episode 184 score 0.01 average score -0.00 epsilon 0.60
# The episode ran for 3 timesteps.
# episode 185 score 0.01 average score -0.00 epsilon 0.60
# The episode ran for 5 timesteps.
# episode 186 score 0.05 average score -0.00 epsilon 0.60
# The episode ran for 4 timesteps.
# episode 187 score 0.00 average score -0.00 epsilon 0.60
# The episode ran for 2 timesteps.
# episode 188 score 0.00 average score -0.00 epsilon 0.60
# The episode ran for 2 timesteps.
# episode 189 score -0.00 average score -0.00 epsilon 0.60
# The episode ran for 2 timesteps.
# episode 190 score 0.01 average score -0.00 epsilon 0.59
# The episode ran for 13 timesteps.
# episode 191 score 0.01 average score -0.00 epsilon 0.59
# The episode ran for 3 timesteps.
# episode 192 score 0.00 average score -0.00 epsilon 0.59
# The episode ran for 3 timesteps.
# episode 193 score 0.03 average score -0.00 epsilon 0.58
# The episode ran for 2 timesteps.
# episode 194 score 0.02 average score -0.00 epsilon 0.58
# The episode ran for 4 timesteps.
# episode 195 score -0.02 average score -0.00 epsilon 0.58
# The episode ran for 2 timesteps.
# episode 196 score -0.00 average score -0.00 epsilon 0.58
# The episode ran for 3 timesteps.
# episode 197 score 0.00 average score 0.00 epsilon 0.58
# The episode ran for 7 timesteps.
# episode 198 score 0.03 average score 0.00 epsilon 0.58
# The episode ran for 2 timesteps.
# episode 199 score 0.00 average score 0.00 epsilon 0.57
# The episode ran for 3 timesteps.
# episode 200 score 0.01 average score 0.00 epsilon 0.57
# The episode ran for 7 timesteps.
# episode 201 score 0.01 average score 0.00 epsilon 0.57
# The episode ran for 6 timesteps.
# episode 202 score 0.00 average score 0.00 epsilon 0.57
# The episode ran for 3 timesteps.
# episode 203 score 0.01 average score 0.00 epsilon 0.57
# The episode ran for 2 timesteps.
# episode 204 score -0.02 average score 0.00 epsilon 0.56
# The episode ran for 15 timesteps.
# episode 205 score 0.04 average score 0.00 epsilon 0.56
# The episode ran for 8 timesteps.
# episode 206 score -0.07 average score 0.00 epsilon 0.55
# The episode ran for 9 timesteps.
# episode 207 score -0.00 average score 0.00 epsilon 0.55
# The episode ran for 3 timesteps.
# episode 208 score -0.00 average score 0.00 epsilon 0.55
# The episode ran for 2 timesteps.
# episode 209 score 0.01 average score 0.00 epsilon 0.55
# The episode ran for 4 timesteps.
# episode 210 score -0.01 average score 0.00 epsilon 0.54
# The episode ran for 3 timesteps.
# episode 211 score 0.01 average score 0.00 epsilon 0.54
# The episode ran for 4 timesteps.
# episode 212 score 0.01 average score 0.00 epsilon 0.54
# The episode ran for 5 timesteps.
# episode 213 score 0.01 average score 0.00 epsilon 0.54
# The episode ran for 2 timesteps.
# episode 214 score 0.00 average score 0.00 epsilon 0.54
# The episode ran for 3 timesteps.
# episode 215 score 0.00 average score 0.00 epsilon 0.54
# The episode ran for 3 timesteps.
# episode 216 score -0.00 average score 0.00 epsilon 0.53
# The episode ran for 3 timesteps.
# episode 217 score -0.00 average score 0.00 epsilon 0.53
# The episode ran for 2 timesteps.
# episode 218 score 0.01 average score 0.00 epsilon 0.53
# The episode ran for 2 timesteps.
# episode 219 score 0.02 average score 0.00 epsilon 0.53
# The episode ran for 3 timesteps.
# episode 220 score -0.01 average score 0.00 epsilon 0.53
# The episode ran for 3 timesteps.
# episode 221 score 0.01 average score 0.00 epsilon 0.53
# The episode ran for 2 timesteps.
# episode 222 score 0.01 average score 0.00 epsilon 0.53
# The episode ran for 3 timesteps.
# episode 223 score 0.00 average score 0.00 epsilon 0.52
# The episode ran for 7 timesteps.
# episode 224 score 0.02 average score 0.00 epsilon 0.52
# The episode ran for 5 timesteps.
# episode 225 score 0.08 average score 0.00 epsilon 0.52
# The episode ran for 4 timesteps.
# episode 226 score -0.01 average score 0.00 epsilon 0.52
# The episode ran for 5 timesteps.
# episode 227 score 0.01 average score 0.00 epsilon 0.51
# The episode ran for 4 timesteps.
# episode 228 score 0.01 average score 0.00 epsilon 0.51
# The episode ran for 11 timesteps.
# episode 229 score 0.05 average score 0.00 epsilon 0.51
# The episode ran for 2 timesteps.
# episode 230 score 0.00 average score 0.00 epsilon 0.51
# The episode ran for 7 timesteps.
# episode 231 score 0.02 average score 0.00 epsilon 0.50
# The episode ran for 3 timesteps.
# episode 232 score 0.00 average score 0.00 epsilon 0.50
# The episode ran for 5 timesteps.
# episode 233 score -0.00 average score 0.00 epsilon 0.50
# The episode ran for 5 timesteps.
# episode 234 score 0.01 average score 0.00 epsilon 0.50
# The episode ran for 3 timesteps.
# episode 235 score -0.00 average score 0.00 epsilon 0.49
# The episode ran for 12 timesteps.
# episode 236 score -0.06 average score 0.00 epsilon 0.49
# The episode ran for 3 timesteps.
# episode 237 score 0.00 average score 0.00 epsilon 0.49
# The episode ran for 2 timesteps.
# episode 238 score -0.01 average score 0.00 epsilon 0.49
# The episode ran for 5 timesteps.
# episode 239 score -0.01 average score 0.00 epsilon 0.48
# The episode ran for 2 timesteps.
# episode 240 score 0.00 average score 0.00 epsilon 0.48
# The episode ran for 2 timesteps.
# episode 241 score -0.00 average score 0.00 epsilon 0.48
# The episode ran for 4 timesteps.
# episode 242 score -0.00 average score 0.00 epsilon 0.48
# The episode ran for 4 timesteps.
# episode 243 score -0.01 average score 0.00 epsilon 0.48
# The episode ran for 4 timesteps.
# episode 244 score -0.00 average score 0.00 epsilon 0.48
# The episode ran for 3 timesteps.
# episode 245 score 0.00 average score 0.00 epsilon 0.47
# The episode ran for 6 timesteps.
# episode 246 score -0.01 average score 0.00 epsilon 0.47
# The episode ran for 2 timesteps.
# episode 247 score -0.00 average score 0.00 epsilon 0.47
# The episode ran for 4 timesteps.
# episode 248 score -0.11 average score 0.00 epsilon 0.47
# The episode ran for 5 timesteps.
# episode 249 score -0.01 average score 0.00 epsilon 0.47
# The episode ran for 8 timesteps.
# episode 250 score 0.00 average score 0.00 epsilon 0.46
# The episode ran for 4 timesteps.
# episode 251 score 0.01 average score 0.00 epsilon 0.46
# The episode ran for 3 timesteps.
# episode 252 score 0.01 average score 0.00 epsilon 0.46
# The episode ran for 8 timesteps.
# episode 253 score 0.05 average score 0.00 epsilon 0.45
# The episode ran for 5 timesteps.
# episode 254 score -0.01 average score 0.00 epsilon 0.45
# The episode ran for 3 timesteps.
# episode 255 score -0.01 average score 0.00 epsilon 0.45
# The episode ran for 3 timesteps.
# episode 256 score 0.01 average score 0.00 epsilon 0.45
# The episode ran for 7 timesteps.
# episode 257 score -0.03 average score 0.00 epsilon 0.44
# The episode ran for 3 timesteps.
# episode 258 score 0.01 average score 0.00 epsilon 0.44
# The episode ran for 10 timesteps.
# episode 259 score -0.00 average score 0.00 epsilon 0.44
# The episode ran for 9 timesteps.
# episode 260 score 0.00 average score 0.00 epsilon 0.43
# The episode ran for 2 timesteps.
# episode 261 score 0.01 average score 0.00 epsilon 0.43
# The episode ran for 5 timesteps.
# episode 262 score -0.01 average score 0.00 epsilon 0.43
# The episode ran for 3 timesteps.
# episode 263 score -0.01 average score 0.00 epsilon 0.43
# The episode ran for 4 timesteps.
# episode 264 score 0.00 average score 0.00 epsilon 0.43
# The episode ran for 2 timesteps.
# episode 265 score -0.01 average score 0.00 epsilon 0.43
# The episode ran for 5 timesteps.
# episode 266 score -0.01 average score 0.00 epsilon 0.42
# The episode ran for 9 timesteps.
# episode 267 score -0.02 average score 0.00 epsilon 0.42
# The episode ran for 8 timesteps.
# episode 268 score -0.03 average score -0.00 epsilon 0.41
# The episode ran for 2 timesteps.
# episode 269 score 0.00 average score -0.00 epsilon 0.41
# The episode ran for 2 timesteps.
# episode 270 score -0.00 average score -0.00 epsilon 0.41
# The episode ran for 5 timesteps.
# episode 271 score -0.00 average score -0.00 epsilon 0.41
# The episode ran for 3 timesteps.
# episode 272 score -0.00 average score -0.00 epsilon 0.41
# The episode ran for 5 timesteps.
# episode 273 score -0.01 average score -0.00 epsilon 0.41
# The episode ran for 9 timesteps.
# episode 274 score -0.01 average score 0.00 epsilon 0.40
# The episode ran for 2 timesteps.
# episode 275 score -0.00 average score 0.00 epsilon 0.40
# The episode ran for 3 timesteps.
# episode 276 score 0.01 average score 0.00 epsilon 0.40
# The episode ran for 2 timesteps.
# episode 277 score 0.00 average score 0.00 epsilon 0.40
# The episode ran for 6 timesteps.
# episode 278 score -0.00 average score 0.00 epsilon 0.40
# The episode ran for 6 timesteps.
# episode 279 score -0.01 average score 0.00 epsilon 0.39
# The episode ran for 5 timesteps.
# episode 280 score 0.04 average score 0.00 epsilon 0.39
# The episode ran for 24 timesteps.
# episode 281 score -0.20 average score -0.00 epsilon 0.38
# The episode ran for 7 timesteps.
# episode 282 score -0.02 average score -0.00 epsilon 0.37
# The episode ran for 2 timesteps.
# episode 283 score 0.00 average score -0.00 epsilon 0.37
# The episode ran for 2 timesteps.
# episode 284 score 0.01 average score -0.00 epsilon 0.37
# The episode ran for 3 timesteps.
# episode 285 score 0.00 average score -0.00 epsilon 0.37
# The episode ran for 5 timesteps.
# episode 286 score -0.00 average score -0.00 epsilon 0.37
# The episode ran for 7 timesteps.
# episode 287 score 0.02 average score -0.00 epsilon 0.36
# The episode ran for 3 timesteps.
# episode 288 score -0.01 average score -0.00 epsilon 0.36
# The episode ran for 6 timesteps.
# episode 289 score -0.10 average score -0.00 epsilon 0.36
# The episode ran for 3 timesteps.
# episode 290 score -0.00 average score -0.00 epsilon 0.36
# The episode ran for 2 timesteps.
# episode 291 score 0.00 average score -0.00 epsilon 0.36
# The episode ran for 19 timesteps.
# episode 292 score -0.01 average score -0.00 epsilon 0.35
# The episode ran for 2 timesteps.
# episode 293 score -0.00 average score -0.00 epsilon 0.35
# The episode ran for 5 timesteps.
# episode 294 score 0.04 average score -0.00 epsilon 0.34
# The episode ran for 8 timesteps.
# episode 295 score -0.09 average score -0.00 epsilon 0.34
# The episode ran for 9 timesteps.
# episode 296 score -0.09 average score -0.00 epsilon 0.34
# The episode ran for 11 timesteps.
# episode 297 score 0.00 average score -0.00 epsilon 0.33
# The episode ran for 18 timesteps.
# episode 298 score 0.25 average score -0.00 epsilon 0.32
# The episode ran for 3 timesteps.
# episode 299 score 0.00 average score -0.00 epsilon 0.32
# The episode ran for 3 timesteps.
# episode 300 score 0.00 average score -0.00 epsilon 0.32
# The episode ran for 10 timesteps.
# episode 301 score 0.02 average score -0.00 epsilon 0.31
# The episode ran for 7 timesteps.
# episode 302 score -0.01 average score -0.00 epsilon 0.31
# The episode ran for 4 timesteps.
# episode 303 score 0.02 average score -0.00 epsilon 0.31
# The episode ran for 6 timesteps.
# episode 304 score 0.00 average score -0.00 epsilon 0.31
# The episode ran for 5 timesteps.
# episode 305 score -0.02 average score -0.00 epsilon 0.30
# The episode ran for 2 timesteps.
# episode 306 score -0.00 average score -0.00 epsilon 0.30
# The episode ran for 5 timesteps.
# episode 307 score 0.01 average score -0.00 epsilon 0.30
# The episode ran for 10 timesteps.
# episode 308 score 0.01 average score -0.00 epsilon 0.29
# The episode ran for 3 timesteps.
# episode 309 score 0.01 average score -0.00 epsilon 0.29
# The episode ran for 10 timesteps.
# episode 310 score 0.02 average score -0.00 epsilon 0.29
# The episode ran for 3 timesteps.
# episode 311 score -0.01 average score -0.00 epsilon 0.29
# The episode ran for 20 timesteps.
# episode 312 score 0.02 average score -0.00 epsilon 0.28
# The episode ran for 4 timesteps.
# episode 313 score -0.00 average score -0.00 epsilon 0.27
# The episode ran for 3 timesteps.
# episode 314 score -0.00 average score -0.00 epsilon 0.27
# The episode ran for 7 timesteps.
# episode 315 score -0.04 average score -0.00 epsilon 0.27
# The episode ran for 4 timesteps.
# episode 316 score 0.03 average score -0.00 epsilon 0.27
# The episode ran for 5 timesteps.
# episode 317 score -0.00 average score -0.00 epsilon 0.26
# The episode ran for 4 timesteps.
# episode 318 score 0.04 average score -0.00 epsilon 0.26
# The episode ran for 3 timesteps.
# episode 319 score -0.01 average score -0.00 epsilon 0.26
# The episode ran for 8 timesteps.
# episode 320 score -0.02 average score -0.00 epsilon 0.26
# The episode ran for 11 timesteps.
# episode 321 score 0.07 average score -0.00 epsilon 0.25
# The episode ran for 4 timesteps.
# episode 322 score 0.02 average score -0.00 epsilon 0.25
# The episode ran for 8 timesteps.
# episode 323 score 0.01 average score -0.00 epsilon 0.25
# The episode ran for 5 timesteps.
# episode 324 score 0.00 average score -0.00 epsilon 0.24
# The episode ran for 17 timesteps.
# episode 325 score 0.21 average score 0.00 epsilon 0.23
# The episode ran for 2 timesteps.
# episode 326 score 0.00 average score 0.00 epsilon 0.23
# The episode ran for 5 timesteps.
# episode 327 score 0.00 average score 0.00 epsilon 0.23
# The episode ran for 3 timesteps.
# episode 328 score -0.00 average score -0.00 epsilon 0.23
# The episode ran for 3 timesteps.
# episode 329 score 0.00 average score -0.00 epsilon 0.23
# The episode ran for 3 timesteps.
# episode 330 score -0.01 average score -0.00 epsilon 0.23
# The episode ran for 6 timesteps.
# episode 331 score 0.00 average score -0.00 epsilon 0.22
# The episode ran for 7 timesteps.
# episode 332 score -0.00 average score -0.00 epsilon 0.22
# The episode ran for 12 timesteps.
# episode 333 score -0.01 average score -0.00 epsilon 0.21
# The episode ran for 7 timesteps.
# episode 334 score 0.00 average score -0.00 epsilon 0.21
# The episode ran for 2 timesteps.
# episode 335 score 0.01 average score -0.00 epsilon 0.21
# The episode ran for 7 timesteps.
# episode 336 score -0.01 average score -0.00 epsilon 0.21
# The episode ran for 4 timesteps.
# episode 337 score 0.01 average score -0.00 epsilon 0.20
# The episode ran for 7 timesteps.
# episode 338 score 0.00 average score -0.00 epsilon 0.20
# The episode ran for 2 timesteps.
# episode 339 score 0.00 average score -0.00 epsilon 0.20
# The episode ran for 47 timesteps.
# episode 340 score -0.17 average score -0.00 epsilon 0.18
# The episode ran for 3 timesteps.
# episode 341 score 0.00 average score -0.00 epsilon 0.17
# The episode ran for 7 timesteps.
# episode 342 score -0.01 average score -0.00 epsilon 0.17
# The episode ran for 5 timesteps.
# episode 343 score 0.01 average score -0.00 epsilon 0.17
# The episode ran for 4 timesteps.
# episode 344 score -0.01 average score -0.00 epsilon 0.17
# The episode ran for 6 timesteps.
# episode 345 score 0.01 average score -0.00 epsilon 0.16
# The episode ran for 3 timesteps.
# episode 346 score 0.00 average score -0.00 epsilon 0.16
# The episode ran for 4 timesteps.
# episode 347 score -0.01 average score -0.00 epsilon 0.16
# The episode ran for 4 timesteps.
# episode 348 score 0.02 average score -0.00 epsilon 0.16
# The episode ran for 4 timesteps.
# episode 349 score -0.01 average score -0.00 epsilon 0.16
# The episode ran for 6 timesteps.
# episode 350 score 0.01 average score -0.00 epsilon 0.15
# The episode ran for 8 timesteps.
# episode 351 score 0.01 average score -0.00 epsilon 0.15
# The episode ran for 7 timesteps.
# episode 352 score -0.01 average score -0.00 epsilon 0.15
# The episode ran for 3 timesteps.
# episode 353 score -0.00 average score -0.00 epsilon 0.14
# The episode ran for 10 timesteps.
# episode 354 score 0.01 average score -0.00 epsilon 0.14
# The episode ran for 11 timesteps.
# episode 355 score 0.07 average score 0.00 epsilon 0.13
# The episode ran for 16 timesteps.
# episode 356 score 0.00 average score 0.00 epsilon 0.13
# The episode ran for 6 timesteps.
# episode 357 score 0.04 average score 0.00 epsilon 0.12
# The episode ran for 2 timesteps.
# episode 358 score 0.00 average score 0.00 epsilon 0.12
# The episode ran for 28 timesteps.
# episode 359 score -0.14 average score -0.00 epsilon 0.11
# The episode ran for 2 timesteps.
# episode 360 score -0.00 average score -0.00 epsilon 0.11
# The episode ran for 5 timesteps.
# episode 361 score -0.00 average score -0.00 epsilon 0.10
# The episode ran for 4 timesteps.
# episode 362 score 0.01 average score -0.00 epsilon 0.10
# The episode ran for 4 timesteps.
# episode 363 score 0.00 average score -0.00 epsilon 0.10
# The episode ran for 5 timesteps.
# episode 364 score 0.03 average score -0.00 epsilon 0.10
# The episode ran for 60 timesteps.
# episode 365 score 0.74 average score 0.01 epsilon 0.07
# The episode ran for 4 timesteps.
# episode 366 score -0.01 average score 0.01 epsilon 0.07
# The episode ran for 5 timesteps.
# episode 367 score 0.02 average score 0.01 epsilon 0.06
# The episode ran for 25 timesteps.
# episode 368 score 0.04 average score 0.01 epsilon 0.05
# The episode ran for 3 timesteps.
# episode 369 score 0.00 average score 0.01 epsilon 0.05
# The episode ran for 2 timesteps.
# episode 370 score -0.00 average score 0.01 epsilon 0.05
# The episode ran for 2 timesteps.
# episode 371 score -0.00 average score 0.01 epsilon 0.05
# The episode ran for 5 timesteps.
# episode 372 score 0.01 average score 0.01 epsilon 0.04
# The episode ran for 6 timesteps.
# episode 373 score -0.00 average score 0.01 epsilon 0.04
# The episode ran for 3 timesteps.
# episode 374 score 0.01 average score 0.01 epsilon 0.04
# The episode ran for 5 timesteps.
# episode 375 score 0.00 average score 0.01 epsilon 0.04
# The episode ran for 8 timesteps.
# episode 376 score -0.01 average score 0.01 epsilon 0.03
# The episode ran for 17 timesteps.
# episode 377 score 0.02 average score 0.01 epsilon 0.03
# The episode ran for 7 timesteps.
# episode 378 score -0.18 average score 0.01 epsilon 0.02
# The episode ran for 2 timesteps.
# episode 379 score 0.01 average score 0.01 epsilon 0.02
# The episode ran for 7 timesteps.
# episode 380 score -0.00 average score 0.01 epsilon 0.02
# The episode ran for 6 timesteps.
# episode 381 score 0.06 average score 0.01 epsilon 0.01
# The episode ran for 2 timesteps.
# episode 382 score 0.00 average score 0.01 epsilon 0.01
# The episode ran for 10 timesteps.
# episode 383 score 0.02 average score 0.01 epsilon 0.01
# The episode ran for 2 timesteps.
# episode 384 score 0.00 average score 0.01 epsilon 0.01
# The episode ran for 7 timesteps.
# episode 385 score -0.00 average score 0.01 epsilon 0.01
# The episode ran for 4 timesteps.
# episode 386 score 0.00 average score 0.01 epsilon 0.01
# The episode ran for 3 timesteps.
# episode 387 score -0.03 average score 0.01 epsilon 0.01
# The episode ran for 4 timesteps.
# episode 388 score -0.01 average score 0.01 epsilon 0.01
# The episode ran for 52 timesteps.
# episode 389 score -0.39 average score 0.01 epsilon 0.01
# The episode ran for 2 timesteps.
# episode 390 score 0.00 average score 0.01 epsilon 0.01
# The episode ran for 4 timesteps.
# episode 391 score -0.01 average score 0.01 epsilon 0.01
# The episode ran for 4 timesteps.
# episode 392 score 0.00 average score 0.01 epsilon 0.01
# The episode ran for 5 timesteps.
# episode 393 score 0.00 average score 0.01 epsilon 0.01
# The episode ran for 7 timesteps.
# episode 394 score 0.00 average score 0.01 epsilon 0.01
# The episode ran for 2 timesteps.
# episode 395 score 0.00 average score 0.01 epsilon 0.01
# The episode ran for 5 timesteps.
# episode 396 score -0.00 average score 0.01 epsilon 0.01
# The episode ran for 3 timesteps.
# episode 397 score -0.01 average score 0.01 epsilon 0.01
# The episode ran for 4 timesteps.
# episode 398 score -0.01 average score 0.01 epsilon 0.01
# The episode ran for 3 timesteps.
# episode 399 score -0.01 average score 0.01 epsilon 0.01
# The episode ran for 6 timesteps.
# episode 400 score -0.03 average score 0.00 epsilon 0.01
# The episode ran for 5 timesteps.
# episode 401 score 0.00 average score 0.00 epsilon 0.01
# The episode ran for 6 timesteps.
# episode 402 score 0.01 average score 0.01 epsilon 0.01
# The episode ran for 6 timesteps.
# episode 403 score -0.01 average score 0.00 epsilon 0.01
# The episode ran for 2 timesteps.
# episode 404 score 0.01 average score 0.00 epsilon 0.01
# The episode ran for 5 timesteps.
# episode 405 score 0.00 average score 0.01 epsilon 0.01
# The episode ran for 2 timesteps.
# episode 406 score -0.01 average score 0.00 epsilon 0.01
# The episode ran for 5 timesteps.
# episode 407 score -0.00 average score 0.00 epsilon 0.01
# The episode ran for 4 timesteps.
# episode 408 score -0.01 average score 0.00 epsilon 0.01
# The episode ran for 5 timesteps.
# episode 409 score -0.02 average score 0.00 epsilon 0.01
# The episode ran for 3 timesteps.
# episode 410 score -0.00 average score 0.00 epsilon 0.01
# The episode ran for 2 timesteps.
# episode 411 score 0.01 average score 0.00 epsilon 0.01
# The episode ran for 2 timesteps.
# episode 412 score 0.00 average score 0.00 epsilon 0.01
# The episode ran for 5 timesteps.
# episode 413 score 0.00 average score 0.00 epsilon 0.01
# The episode ran for 5 timesteps.
# episode 414 score 0.01 average score 0.00 epsilon 0.01
# The episode ran for 7 timesteps.
# episode 415 score 0.01 average score 0.01 epsilon 0.01
# The episode ran for 11 timesteps.
# episode 416 score 0.02 average score 0.00 epsilon 0.01
# The episode ran for 20 timesteps.
# episode 417 score -0.48 average score 0.00 epsilon 0.01
# The episode ran for 5 timesteps.
# episode 418 score -0.00 average score -0.00 epsilon 0.01
# The episode ran for 35 timesteps.
# episode 419 score -0.00 average score -0.00 epsilon 0.01
# The episode ran for 25 timesteps.
# episode 420 score -0.19 average score -0.00 epsilon 0.01
# The episode ran for 9 timesteps.
# episode 421 score -0.04 average score -0.00 epsilon 0.01
# The episode ran for 134 timesteps.
# episode 422 score 0.94 average score 0.01 epsilon 0.01
# The episode ran for 3 timesteps.
# episode 423 score -0.01 average score 0.01 epsilon 0.01
# The episode ran for 6 timesteps.
# episode 424 score 0.01 average score 0.01 epsilon 0.01
# The episode ran for 8 timesteps.
# episode 425 score 0.07 average score 0.00 epsilon 0.01
# The episode ran for 12 timesteps.
# episode 426 score -0.01 average score 0.00 epsilon 0.01
# The episode ran for 10 timesteps.
# episode 427 score 0.01 average score 0.00 epsilon 0.01
# The episode ran for 6 timesteps.
# episode 428 score 0.01 average score 0.00 epsilon 0.01
# The episode ran for 2 timesteps.
# episode 429 score 0.00 average score 0.00 epsilon 0.01
# The episode ran for 6 timesteps.
# episode 430 score 0.00 average score 0.00 epsilon 0.01
# The episode ran for 4 timesteps.
# episode 431 score 0.01 average score 0.00 epsilon 0.01
# The episode ran for 4 timesteps.
# episode 432 score -0.01 average score 0.00 epsilon 0.01
# The episode ran for 5 timesteps.
# episode 433 score -0.02 average score 0.00 epsilon 0.01
# The episode ran for 5 timesteps.
# episode 434 score 0.03 average score 0.01 epsilon 0.01
# The episode ran for 5 timesteps.
# episode 435 score -0.05 average score 0.00 epsilon 0.01
# The episode ran for 14 timesteps.
# episode 436 score -0.01 average score 0.00 epsilon 0.01
# The episode ran for 4 timesteps.
# episode 437 score 0.02 average score 0.00 epsilon 0.01
# The episode ran for 13 timesteps.
# episode 438 score 0.03 average score 0.00 epsilon 0.01
# The episode ran for 8 timesteps.
# episode 439 score 0.00 average score 0.00 epsilon 0.01
# The episode ran for 13 timesteps.
# episode 440 score 0.00 average score 0.01 epsilon 0.01
# The episode ran for 4 timesteps.
# episode 441 score -0.00 average score 0.01 epsilon 0.01
# The episode ran for 8 timesteps.
# episode 442 score 0.00 average score 0.01 epsilon 0.01
# The episode ran for 2 timesteps.
# episode 443 score 0.02 average score 0.01 epsilon 0.01
# The episode ran for 3 timesteps.
# episode 444 score 0.00 average score 0.01 epsilon 0.01
# The episode ran for 11 timesteps.
# episode 445 score -0.07 average score 0.01 epsilon 0.01
# The episode ran for 13 timesteps.
# episode 446 score -0.06 average score 0.01 epsilon 0.01
# The episode ran for 6 timesteps.
# episode 447 score 0.00 average score 0.01 epsilon 0.01
# The episode ran for 5 timesteps.
# episode 448 score -0.02 average score 0.01 epsilon 0.01
# The episode ran for 8 timesteps.
# episode 449 score 0.13 average score 0.01 epsilon 0.01
# The episode ran for 2 timesteps.
# episode 450 score -0.00 average score 0.01 epsilon 0.01
# The episode ran for 5 timesteps.
# episode 451 score -0.02 average score 0.01 epsilon 0.01
# The episode ran for 3 timesteps.
# episode 452 score -0.00 average score 0.01 epsilon 0.01
# The episode ran for 4 timesteps.
# episode 453 score 0.00 average score 0.01 epsilon 0.01
# The episode ran for 3 timesteps.
# episode 454 score 0.01 average score 0.01 epsilon 0.01
# The episode ran for 5 timesteps.
# episode 455 score -0.01 average score 0.01 epsilon 0.01
# The episode ran for 5 timesteps.
# episode 456 score 0.00 average score 0.01 epsilon 0.01
# The episode ran for 2 timesteps.
# episode 457 score -0.01 average score 0.01 epsilon 0.01
# The episode ran for 6 timesteps.
# episode 458 score -0.00 average score 0.00 epsilon 0.01
# The episode ran for 6 timesteps.
# episode 459 score -0.03 average score 0.01 epsilon 0.01
# The episode ran for 2 timesteps.
# episode 460 score -0.01 average score 0.01 epsilon 0.01
# The episode ran for 9 timesteps.
# episode 461 score 0.01 average score 0.01 epsilon 0.01
# The episode ran for 4 timesteps.
# episode 462 score 0.03 average score 0.01 epsilon 0.01
# The episode ran for 19 timesteps.
# episode 463 score -0.04 average score 0.01 epsilon 0.01
# The episode ran for 296 timesteps.
# episode 464 score 3.39 average score 0.04 epsilon 0.01
# The episode ran for 104 timesteps.
# episode 465 score 3.52 average score 0.07 epsilon 0.01
# The episode ran for 338 timesteps.
# episode 466 score 81.63 average score 0.88 epsilon 0.01
# The episode ran for 78 timesteps.
# episode 467 score 1.97 average score 0.90 epsilon 0.01
# The episode ran for 112 timesteps.
# episode 468 score -8.53 average score 0.82 epsilon 0.01
# The episode ran for 62 timesteps.
# episode 469 score 0.10 average score 0.82 epsilon 0.01
# The episode ran for 250 timesteps.
# episode 470 score 0.04 average score 0.82 epsilon 0.01
# The episode ran for 119 timesteps.
# episode 471 score -0.00 average score 0.82 epsilon 0.01
# The episode ran for 107 timesteps.
# episode 472 score 0.03 average score 0.82 epsilon 0.01
# The episode ran for 438 timesteps.
# episode 473 score 0.13 average score 0.82 epsilon 0.01
# The episode ran for 313 timesteps.
# episode 474 score 4.09 average score 0.86 epsilon 0.01
# The episode ran for 70 timesteps.
# episode 475 score -1.36 average score 0.85 epsilon 0.01
# The episode ran for 145 timesteps.
# episode 476 score 3.70 average score 0.88 epsilon 0.01
# The episode ran for 51 timesteps.
# episode 477 score 0.19 average score 0.89 epsilon 0.01
# The episode ran for 322 timesteps.
# episode 478 score -14.70 average score 0.74 epsilon 0.01
# The episode ran for 96 timesteps.
# episode 479 score -1.63 average score 0.72 epsilon 0.01
# The episode ran for 153 timesteps.
# episode 480 score -4.67 average score 0.68 epsilon 0.01
# The episode ran for 250 timesteps.
# episode 481 score 23.89 average score 0.92 epsilon 0.01
# The episode ran for 548 timesteps.
# episode 482 score -77.30 average score 0.14 epsilon 0.01
# The episode ran for 427 timesteps.
# episode 483 score -19.06 average score -0.05 epsilon 0.01
# The episode ran for 885 timesteps.
# episode 484 score -59.41 average score -0.64 epsilon 0.01
# The episode ran for 263 timesteps.
# episode 485 score -4.28 average score -0.68 epsilon 0.01
# The episode ran for 136 timesteps.
# episode 486 score -1.29 average score -0.70 epsilon 0.01
# The episode ran for 66 timesteps.
# episode 487 score -0.11 average score -0.70 epsilon 0.01
# The episode ran for 216 timesteps.
# episode 488 score -5.77 average score -0.76 epsilon 0.01
# The episode ran for 12 timesteps.
# episode 489 score -0.11 average score -0.75 epsilon 0.01
# The episode ran for 20 timesteps.
# episode 490 score 0.63 average score -0.75 epsilon 0.01
# The episode ran for 122 timesteps.
# episode 491 score 0.51 average score -0.74 epsilon 0.01
# The episode ran for 806 timesteps.
# episode 492 score -99.81 average score -1.74 epsilon 0.01
# The episode ran for 76 timesteps.
# episode 493 score -1.78 average score -1.76 epsilon 0.01
# The episode ran for 211 timesteps.
# episode 494 score 14.83 average score -1.61 epsilon 0.01
# The episode ran for 744 timesteps.
# episode 495 score -5.07 average score -1.66 epsilon 0.01
# The episode ran for 673 timesteps.
# episode 496 score -56.33 average score -2.22 epsilon 0.01
# The episode ran for 13 timesteps.
# episode 497 score 0.03 average score -2.22 epsilon 0.01
# The episode ran for 77 timesteps.
# episode 498 score 1.49 average score -2.21 epsilon 0.01
# The episode ran for 31 timesteps.
# episode 499 score -0.10 average score -2.21 epsilon 0.01
# The episode ran for 6 timesteps.
# episode 500 score 0.05 average score -2.21 epsilon 0.01
# The episode ran for 603 timesteps.
# episode 501 score -35.79 average score -2.57 epsilon 0.01
# The episode ran for 270 timesteps.
# episode 502 score 3.58 average score -2.53 epsilon 0.01
# The episode ran for 474 timesteps.
# episode 503 score -42.36 average score -2.95 epsilon 0.01
# The episode ran for 358 timesteps.
# episode 504 score 6.69 average score -2.89 epsilon 0.01
# The episode ran for 28 timesteps.
# episode 505 score 0.87 average score -2.88 epsilon 0.01
# The episode ran for 340 timesteps.
# episode 506 score 15.04 average score -2.73 epsilon 0.01
# The episode ran for 136 timesteps.
# episode 507 score 6.47 average score -2.66 epsilon 0.01
# The episode ran for 21 timesteps.
# episode 508 score 0.89 average score -2.65 epsilon 0.01
# The episode ran for 69 timesteps.
# episode 509 score -0.06 average score -2.65 epsilon 0.01
# The episode ran for 295 timesteps.
# episode 510 score 43.74 average score -2.22 epsilon 0.01
# The episode ran for 448 timesteps.
# episode 511 score 28.88 average score -1.93 epsilon 0.01
# The episode ran for 478 timesteps.
# episode 512 score 44.09 average score -1.49 epsilon 0.01
# The episode ran for 39 timesteps.
# episode 513 score -0.32 average score -1.49 epsilon 0.01
# The episode ran for 154 timesteps.
# episode 514 score 4.26 average score -1.45 epsilon 0.01
# The episode ran for 1562 timesteps.
# episode 515 score 95.42 average score -0.49 epsilon 0.01
# The episode ran for 744 timesteps.
# episode 516 score 83.84 average score 0.34 epsilon 0.01
# The episode ran for 178 timesteps.
# episode 517 score 16.27 average score 0.51 epsilon 0.01
# The episode ran for 304 timesteps.
# episode 518 score -21.32 average score 0.30 epsilon 0.01
# The episode ran for 350 timesteps.
# episode 519 score -13.32 average score 0.17 epsilon 0.01
# The episode ran for 62 timesteps.
# episode 520 score -0.98 average score 0.16 epsilon 0.01
# The episode ran for 200 timesteps.
# episode 521 score -3.18 average score 0.13 epsilon 0.01
# The episode ran for 29 timesteps.
# episode 522 score 0.01 average score 0.12 epsilon 0.01
# The episode ran for 79 timesteps.
# episode 523 score 1.42 average score 0.13 epsilon 0.01
# The episode ran for 2 timesteps.
# episode 524 score 0.01 average score 0.13 epsilon 0.01
# The episode ran for 37 timesteps.
# episode 525 score -2.54 average score 0.11 epsilon 0.01
# The episode ran for 31 timesteps.
# episode 526 score 0.83 average score 0.11 epsilon 0.01
# The episode ran for 36 timesteps.
# episode 527 score -0.04 average score 0.11 epsilon 0.01
# The episode ran for 13 timesteps.
# episode 528 score -0.06 average score 0.11 epsilon 0.01
# The episode ran for 184 timesteps.
# episode 529 score -0.82 average score 0.10 epsilon 0.01
# The episode ran for 222 timesteps.
# episode 530 score 11.81 average score 0.22 epsilon 0.01
# The episode ran for 2 timesteps.
# episode 531 score 0.01 average score 0.22 epsilon 0.01
# The episode ran for 70 timesteps.
# episode 532 score 1.66 average score 0.24 epsilon 0.01
# The episode ran for 29 timesteps.
# episode 533 score 0.24 average score 0.24 epsilon 0.01
# The episode ran for 18 timesteps.
# episode 534 score 0.46 average score 0.25 epsilon 0.01
# The episode ran for 14 timesteps.
# episode 535 score 0.15 average score 0.25 epsilon 0.01
# The episode ran for 9 timesteps.
# episode 536 score 0.37 average score 0.25 epsilon 0.01
# The episode ran for 43 timesteps.
# episode 537 score 0.22 average score 0.25 epsilon 0.01
# The episode ran for 81 timesteps.
# episode 538 score 2.78 average score 0.28 epsilon 0.01
# The episode ran for 3 timesteps.
# ...
# The episode ran for 17 timesteps.
# episode 823 score 0.02 average score -0.30 epsilon 0.01
# The episode ran for 37 timesteps.
# episode 824 score 0.36 average score -0.30 epsilon 0.01
# The episode ran for 53 timesteps.
# episode 825 score 1.13 average score -0.29 epsilon 0.01
# The episode ran for 224 timesteps.
# episode 826 score 4.29 average score -0.26 epsilon 0.01
# The episode ran for 202 timesteps.
# episode 827 score 11.38 average score -0.08 epsilon 0.01
# The episode ran for 55 timesteps.
# episode 828 score -0.67 average score -0.08 epsilon 0.01
# The episode ran for 31 timesteps.
# episode 829 score 0.25 average score -0.09 epsilon 0.01
# The episode ran for 58 timesteps.
# episode 830 score -0.53 average score -0.09 epsilon 0.01
# The episode ran for 6 timesteps.
# episode 831 score 0.06 average score -0.10 epsilon 0.01
# The episode ran for 36 timesteps.
# episode 832 score -0.24 average score -0.16 epsilon 0.01
# The episode ran for 38 timesteps.
# episode 833 score 0.50 average score -0.11 epsilon 0.01
# The episode ran for 93 timesteps.
# episode 834 score 0.40 average score -0.10 epsilon 0.01
# The episode ran for 73 timesteps.
# episode 835 score -0.37 average score -0.09 epsilon 0.01
# The episode ran for 2 timesteps.
# episode 836 score -0.00 average score -0.09 epsilon 0.01
# The episode ran for 98 timesteps.
# episode 837 score 3.56 average score -0.05 epsilon 0.01
# The episode ran for 116 timesteps.
# episode 838 score 0.70 average score -0.04 epsilon 0.01
# The episode ran for 32 timesteps.
# episode 839 score 0.23 average score -0.04 epsilon 0.01
# The episode ran for 112 timesteps.
# episode 840 score 1.22 average score -0.02 epsilon 0.01
# The episode ran for 163 timesteps.
# episode 841 score 16.66 average score 0.33 epsilon 0.01
# The episode ran for 33 timesteps.
# episode 842 score 1.04 average score 0.35 epsilon 0.01
# The episode ran for 55 timesteps.
# episode 843 score 1.34 average score 0.41 epsilon 0.01
# The episode ran for 196 timesteps.
# episode 844 score 7.52 average score 0.51 epsilon 0.01
# The episode ran for 9 timesteps.
# episode 845 score -0.04 average score 0.30 epsilon 0.01
# The episode ran for 188 timesteps.
# episode 846 score 2.48 average score 0.31 epsilon 0.01
# The episode ran for 30 timesteps.
# episode 847 score 0.58 average score 0.32 epsilon 0.01
# The episode ran for 2 timesteps.
# episode 848 score 0.00 average score 0.30 epsilon 0.01
# The episode ran for 18 timesteps.
# episode 849 score 0.14 average score 0.32 epsilon 0.01
# The episode ran for 82 timesteps.
# episode 850 score 0.99 average score 0.29 epsilon 0.01
# The episode ran for 27 timesteps.
# episode 851 score 0.77 average score 0.33 epsilon 0.01
# The episode ran for 2 timesteps.
# episode 852 score 0.00 average score 0.34 epsilon 0.01
# The episode ran for 237 timesteps.
# episode 853 score -0.79 average score 0.30 epsilon 0.01
# The episode ran for 27 timesteps.
# episode 854 score -0.08 average score 0.36 epsilon 0.01
# The episode ran for 58 timesteps.
# episode 855 score -0.50 average score 0.33 epsilon 0.01
# The episode ran for 177 timesteps.
# episode 856 score 5.80 average score 0.38 epsilon 0.01
# The episode ran for 8 timesteps.
# episode 857 score -0.11 average score 0.40 epsilon 0.01
# The episode ran for 257 timesteps.
# episode 858 score 5.44 average score 0.52 epsilon 0.01
# The episode ran for 133 timesteps.
# episode 859 score -3.90 average score 0.47 epsilon 0.01
# The episode ran for 114 timesteps.
# episode 860 score 13.46 average score 0.60 epsilon 0.01
# The episode ran for 116 timesteps.
# episode 861 score 3.22 average score 0.63 epsilon 0.01
# The episode ran for 57 timesteps.
# episode 862 score 0.08 average score 0.95 epsilon 0.01
# The episode ran for 90 timesteps.
# episode 863 score 0.07 average score 0.96 epsilon 0.01
# The episode ran for 204 timesteps.
# episode 864 score -4.50 average score 0.92 epsilon 0.01
# The episode ran for 51 timesteps.
# episode 865 score -0.90 average score 0.91 epsilon 0.01
# The episode ran for 68 timesteps.
# episode 866 score -3.83 average score 0.87 epsilon 0.01
# The episode ran for 105 timesteps.
# episode 867 score -0.22 average score 0.87 epsilon 0.01
# The episode ran for 15 timesteps.
# episode 868 score -0.05 average score 0.87 epsilon 0.01
# The episode ran for 61 timesteps.
# episode 869 score 0.49 average score 0.66 epsilon 0.01
# The episode ran for 183 timesteps.
# episode 870 score -18.74 average score 0.47 epsilon 0.01
# The episode ran for 26 timesteps.
# episode 871 score -0.18 average score 0.48 epsilon 0.01
# The episode ran for 72 timesteps.
# episode 872 score -0.48 average score 0.47 epsilon 0.01
# The episode ran for 61 timesteps.
# episode 873 score -1.78 average score 0.46 epsilon 0.01
# The episode ran for 30 timesteps.
# episode 874 score 1.42 average score 0.47 epsilon 0.01
# The episode ran for 68 timesteps.
# episode 875 score -1.70 average score 0.44 epsilon 0.01
# The episode ran for 80 timesteps.
# episode 876 score 1.35 average score 0.47 epsilon 0.01
# The episode ran for 46 timesteps.
# episode 877 score -0.72 average score 0.47 epsilon 0.01
# The episode ran for 12 timesteps.
# episode 878 score -0.06 average score 0.46 epsilon 0.01
# The episode ran for 15 timesteps.
# episode 879 score -0.25 average score 0.45 epsilon 0.01
# The episode ran for 35 timesteps.
# episode 880 score -0.35 average score 0.52 epsilon 0.01
# The episode ran for 50 timesteps.
# episode 881 score 1.02 average score 0.53 epsilon 0.01
# The episode ran for 81 timesteps.
# episode 882 score 4.28 average score 0.57 epsilon 0.01
# The episode ran for 4 timesteps.
# episode 883 score 0.02 average score 0.57 epsilon 0.01
# The episode ran for 39 timesteps.
# episode 884 score -1.33 average score 0.56 epsilon 0.01
# The episode ran for 37 timesteps.
# episode 885 score 0.60 average score 0.54 epsilon 0.01
# The episode ran for 161 timesteps.
# episode 886 score 3.97 average score 0.58 epsilon 0.01
# The episode ran for 79 timesteps.
# episode 887 score -0.92 average score 0.57 epsilon 0.01
# The episode ran for 99 timesteps.
# episode 888 score 1.99 average score 0.60 epsilon 0.01
# The episode ran for 72 timesteps.
# episode 889 score -1.56 average score 0.58 epsilon 0.01
# The episode ran for 238 timesteps.
# episode 890 score -23.66 average score 0.32 epsilon 0.01
# The episode ran for 151 timesteps.
# episode 891 score 0.59 average score 0.33 epsilon 0.01
# The episode ran for 152 timesteps.
# episode 892 score 1.27 average score 0.34 epsilon 0.01
# The episode ran for 60 timesteps.
# episode 893 score 0.62 average score 0.35 epsilon 0.01
# The episode ran for 100 timesteps.
# episode 894 score -5.08 average score 0.30 epsilon 0.01
# The episode ran for 89 timesteps.
# episode 895 score -0.27 average score 0.29 epsilon 0.01
# The episode ran for 78 timesteps.
# episode 896 score 0.34 average score 0.30 epsilon 0.01
# The episode ran for 83 timesteps.
# episode 897 score -1.22 average score 0.30 epsilon 0.01
# The episode ran for 188 timesteps.
# episode 898 score -18.49 average score 0.12 epsilon 0.01
# The episode ran for 78 timesteps.
# episode 899 score -0.01 average score 0.11 epsilon 0.01
# The episode ran for 29 timesteps.
# episode 900 score -0.17 average score 0.11 epsilon 0.01
# The episode ran for 72 timesteps.
# episode 901 score 1.74 average score 0.17 epsilon 0.01
# The episode ran for 41 timesteps.
# episode 902 score -0.35 average score 0.16 epsilon 0.01
# The episode ran for 16 timesteps.
# episode 903 score -0.32 average score 0.17 epsilon 0.01
# The episode ran for 64 timesteps.
# episode 904 score -2.36 average score 0.16 epsilon 0.01
# The episode ran for 18 timesteps.
# episode 905 score -0.05 average score 0.16 epsilon 0.01
# The episode ran for 34 timesteps.
# episode 906 score -1.12 average score 0.15 epsilon 0.01
# The episode ran for 68 timesteps.
# episode 907 score -0.48 average score 0.15 epsilon 0.01
# The episode ran for 39 timesteps.
# episode 908 score 0.03 average score 0.13 epsilon 0.01
# The episode ran for 74 timesteps.
# episode 909 score -1.13 average score 0.11 epsilon 0.01
# The episode ran for 3 timesteps.
# episode 910 score 0.03 average score 0.11 epsilon 0.01
# The episode ran for 8 timesteps.
# episode 911 score -0.08 average score 0.07 epsilon 0.01
# The episode ran for 124 timesteps.
# episode 912 score -11.13 average score -0.04 epsilon 0.01
# The episode ran for 2 timesteps.
# episode 913 score -0.02 average score -0.05 epsilon 0.01
# The episode ran for 20 timesteps.
# episode 914 score 0.45 average score -0.05 epsilon 0.01
# The episode ran for 62 timesteps.
# episode 915 score -0.63 average score -0.08 epsilon 0.01
# The episode ran for 39 timesteps.
# episode 916 score 0.23 average score -0.07 epsilon 0.01
# The episode ran for 88 timesteps.
# episode 917 score 3.72 average score -0.04 epsilon 0.01
# The episode ran for 4 timesteps.
# episode 918 score -0.03 average score -0.04 epsilon 0.01
# The episode ran for 67 timesteps.
# episode 919 score 0.21 average score -0.03 epsilon 0.01
# The episode ran for 10 timesteps.
# episode 920 score 0.17 average score -0.03 epsilon 0.01
# The episode ran for 28 timesteps.
# episode 921 score -0.06 average score -0.03 epsilon 0.01
# The episode ran for 84 timesteps.
# episode 922 score -3.54 average score -0.07 epsilon 0.01
# The episode ran for 55 timesteps.
# episode 923 score -0.30 average score -0.07 epsilon 0.01
# The episode ran for 90 timesteps.
# episode 924 score -1.79 average score -0.09 epsilon 0.01
# The episode ran for 4 timesteps.
# episode 925 score 0.00 average score -0.10 epsilon 0.01
# The episode ran for 93 timesteps.
# episode 926 score 1.10 average score -0.14 epsilon 0.01
# The episode ran for 11 timesteps.
# episode 927 score -0.22 average score -0.25 epsilon 0.01
# The episode ran for 406 timesteps.
# episode 928 score -154.55 average score -1.79 epsilon 0.01
# The episode ran for 197 timesteps.
# episode 929 score 7.94 average score -1.71 epsilon 0.01
# The episode ran for 11 timesteps.
# episode 930 score 0.07 average score -1.71 epsilon 0.01
# The episode ran for 50 timesteps.
# episode 931 score 1.58 average score -1.69 epsilon 0.01
# The episode ran for 116 timesteps.
# episode 932 score 1.00 average score -1.68 epsilon 0.01
# The episode ran for 76 timesteps.
# episode 933 score 7.21 average score -1.61 epsilon 0.01
# The episode ran for 13 timesteps.
# episode 934 score 0.31 average score -1.61 epsilon 0.01
# The episode ran for 38 timesteps.
# episode 935 score -0.12 average score -1.61 epsilon 0.01
# The episode ran for 27 timesteps.
# episode 936 score -0.37 average score -1.61 epsilon 0.01
# The episode ran for 44 timesteps.
# episode 937 score -0.96 average score -1.66 epsilon 0.01
# The episode ran for 86 timesteps.
# episode 938 score -1.95 average score -1.69 epsilon 0.01
# The episode ran for 145 timesteps.
# episode 939 score 4.13 average score -1.65 epsilon 0.01
# The episode ran for 185 timesteps.
# episode 940 score 1.22 average score -1.65 epsilon 0.01
# The episode ran for 132 timesteps.
# episode 941 score 4.24 average score -1.77 epsilon 0.01
# The episode ran for 284 timesteps.
# episode 942 score 8.18 average score -1.70 epsilon 0.01
# The episode ran for 60 timesteps.
# episode 943 score -1.03 average score -1.72 epsilon 0.01
# The episode ran for 101 timesteps.
# episode 944 score -0.24 average score -1.80 epsilon 0.01
# The episode ran for 37 timesteps.
# episode 945 score -0.72 average score -1.81 epsilon 0.01
# The episode ran for 38 timesteps.
# episode 946 score -1.40 average score -1.85 epsilon 0.01
# The episode ran for 45 timesteps.
# episode 947 score 1.63 average score -1.84 epsilon 0.01
# The episode ran for 10 timesteps.
# episode 948 score -0.32 average score -1.84 epsilon 0.01
# The episode ran for 124 timesteps.
# episode 949 score 5.36 average score -1.79 epsilon 0.01
# The episode ran for 173 timesteps.
# episode 950 score -3.07 average score -1.83 epsilon 0.01
# The episode ran for 40 timesteps.
# episode 951 score 0.40 average score -1.83 epsilon 0.01
# The episode ran for 178 timesteps.
# episode 952 score 5.74 average score -1.77 epsilon 0.01
# The episode ran for 31 timesteps.
# episode 953 score 0.34 average score -1.76 epsilon 0.01
# The episode ran for 47 timesteps.
# episode 954 score 0.63 average score -1.76 epsilon 0.01
# The episode ran for 31 timesteps.
# episode 955 score -0.31 average score -1.75 epsilon 0.01
# The episode ran for 63 timesteps.
# episode 956 score -0.01 average score -1.81 epsilon 0.01
# The episode ran for 50 timesteps.
# episode 957 score -2.60 average score -1.84 epsilon 0.01
# The episode ran for 219 timesteps.
# episode 958 score -5.59 average score -1.95 epsilon 0.01
# The episode ran for 152 timesteps.
# episode 959 score -3.58 average score -1.94 epsilon 0.01
# The episode ran for 103 timesteps.
# episode 960 score -6.18 average score -2.14 epsilon 0.01
# The episode ran for 22 timesteps.
# episode 961 score -0.03 average score -2.17 epsilon 0.01
# The episode ran for 40 timesteps.
# episode 962 score -0.17 average score -2.18 epsilon 0.01
# The episode ran for 50 timesteps.
# episode 963 score -0.11 average score -2.18 epsilon 0.01
# The episode ran for 339 timesteps.
# episode 964 score -11.91 average score -2.25 epsilon 0.01
# The episode ran for 116 timesteps.
# episode 965 score -0.13 average score -2.24 epsilon 0.01
# The episode ran for 11 timesteps.
# episode 966 score -0.06 average score -2.21 epsilon 0.01
# The episode ran for 4 timesteps.
# episode 967 score -0.01 average score -2.20 epsilon 0.01
# The episode ran for 9 timesteps.
# episode 968 score -0.00 average score -2.20 epsilon 0.01
# The episode ran for 20 timesteps.
# episode 969 score -0.09 average score -2.21 epsilon 0.01
# The episode ran for 269 timesteps.
# episode 970 score -4.10 average score -2.06 epsilon 0.01
# The episode ran for 16 timesteps.
# episode 971 score -0.04 average score -2.06 epsilon 0.01
# The episode ran for 135 timesteps.
# episode 972 score 3.64 average score -2.02 epsilon 0.01
# The episode ran for 82 timesteps.
# episode 973 score 0.22 average score -2.00 epsilon 0.01
# The episode ran for 135 timesteps.
# episode 974 score 5.85 average score -1.96 epsilon 0.01
# The episode ran for 7 timesteps.
# episode 975 score 0.07 average score -1.94 epsilon 0.01
# The episode ran for 67 timesteps.
# episode 976 score 8.16 average score -1.87 epsilon 0.01
# The episode ran for 39 timesteps.
# episode 977 score -0.60 average score -1.87 epsilon 0.01
# The episode ran for 422 timesteps.
# episode 978 score -37.54 average score -2.24 epsilon 0.01
# The episode ran for 10 timesteps.
# episode 979 score -0.06 average score -2.24 epsilon 0.01
# The episode ran for 81 timesteps.
# episode 980 score 3.06 average score -2.21 epsilon 0.01
# The episode ran for 74 timesteps.
# episode 981 score 1.82 average score -2.20 epsilon 0.01
# The episode ran for 231 timesteps.
# episode 982 score -4.77 average score -2.29 epsilon 0.01
# The episode ran for 63 timesteps.
# episode 983 score -2.62 average score -2.32 epsilon 0.01
# The episode ran for 129 timesteps.
# episode 984 score -11.15 average score -2.42 epsilon 0.01
# The episode ran for 37 timesteps.
# episode 985 score 0.06 average score -2.42 epsilon 0.01
# The episode ran for 285 timesteps.
# episode 986 score 10.84 average score -2.35 epsilon 0.01
# The episode ran for 102 timesteps.
# episode 987 score 2.07 average score -2.32 epsilon 0.01
# The episode ran for 79 timesteps.
# episode 988 score 0.29 average score -2.34 epsilon 0.01
# The episode ran for 111 timesteps.
# episode 989 score 7.17 average score -2.25 epsilon 0.01
# The episode ran for 6 timesteps.
# episode 990 score -0.01 average score -2.02 epsilon 0.01
# The episode ran for 82 timesteps.
# episode 991 score 4.70 average score -1.97 epsilon 0.01
# The episode ran for 175 timesteps.
# episode 992 score -9.11 average score -2.08 epsilon 0.01
# The episode ran for 6 timesteps.
# episode 993 score -0.01 average score -2.08 epsilon 0.01
# The episode ran for 247 timesteps.
# episode 994 score -9.42 average score -2.13 epsilon 0.01
# The episode ran for 87 timesteps.
# episode 995 score 1.22 average score -2.11 epsilon 0.01
# The episode ran for 80 timesteps.
# episode 996 score 6.43 average score -2.05 epsilon 0.01
# The episode ran for 10 timesteps.
# episode 997 score 0.22 average score -2.04 epsilon 0.01
# The episode ran for 2 timesteps.
# episode 998 score 0.00 average score -1.85 epsilon 0.01
# The episode ran for 6 timesteps.
# episode 999 score -0.02 average score -1.85 epsilon 0.01
